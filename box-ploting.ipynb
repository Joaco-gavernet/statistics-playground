# %%
import matplotlib.pyplot as plt

data1 = [14, 12, 21, 28, 20, 65, 26]
x = [2.50, 5.03, 7.60, 11.60, 13.00, 19.60, 26.20, 33.00, 40.00, 50.00, 55.00,]
y = [7.68, 6.95, 6.30, 5.75, 5.01, 1.43, 0.93, 0.72, 0.68, 0.65, 0.56]

plt.figure(figsize=(4, 3))
plt.boxplot(data1)  # Creating plot with two data sets
plt.show()

# Scatter plot for x and y datasets
plt.figure(figsize=(4, 3))
plt.scatter(x, y)
plt.show()

# %%
x3 = [4, 4.2, 4.4, 4.6, 4.8, 5, 5.2, 5.4, 5.6, 5.8]
y3 = [8.7, 8.8, 8.3, 8.7, 8.0, 8.1, 8.0, 7.7, 7.5, 7.2]
plt.figure(figsize=(4, 3))
plt.scatter(x3, y3)
plt.show()

# %%
x6 = [40, 20, 25, 20, 30, 50, 40, 20, 50, 40, 25, 50]
y6 = [385, 400, 395, 365, 475, 440, 490, 420, 560, 525, 480, 510]
plt.figure(figsize=(4, 3))
plt.scatter(x6, y6)
plt.show()
